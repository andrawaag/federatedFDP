# %%
import rdflib
import pandas as pd
import requests
import yaml
import matplotlib.pyplot as plt
from IPython.display import display, Markdown
from shexer.shaper import Shaper
from shexer.consts import NT, TURTLE

# %%
title = "EJP-RD index"
index = 'https://index.vp.ejprarediseases.org'

markdown = f"""
[{title}]({index})
=================
"""
display(Markdown(markdown))
# Out:
# [EJP-RD index](https://index.vp.ejprarediseases.org)
# =================

# %%
url = index+'/index/entries/all'
headers = {'accept': 'application/json'}

response = requests.get(url, headers=headers)
data = response.json()

df = pd.DataFrame(data)
df = df.style.set_caption('FDPs indexed in the EJP-RD Index')
df
# Out:
# <style type="text/css">
# </style>
# <table id="T_bcf00">
#   <caption>FDPs indexed in the EJP-RD Index</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcf00_level0_col0" class="col_heading level0 col0" >uuid</th>
#       <th id="T_bcf00_level0_col1" class="col_heading level0 col1" >clientUrl</th>
#       <th id="T_bcf00_level0_col2" class="col_heading level0 col2" >state</th>
#       <th id="T_bcf00_level0_col3" class="col_heading level0 col3" >registrationTime</th>
#       <th id="T_bcf00_level0_col4" class="col_heading level0 col4" >modificationTime</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcf00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bcf00_row0_col0" class="data row0 col0" >cc94cde5-74c5-4256-bbf1-50ec3fad7319</td>
#       <td id="T_bcf00_row0_col1" class="data row0 col1" >https://w3id.org/duchenne-fdp</td>
#       <td id="T_bcf00_row0_col2" class="data row0 col2" >ACTIVE</td>
#       <td id="T_bcf00_row0_col3" class="data row0 col3" >2023-02-25T14:41:17.281Z</td>
#       <td id="T_bcf00_row0_col4" class="data row0 col4" >2023-05-12T10:50:06.647Z</td>
#     </tr>
#     <tr>
#       <th id="T_bcf00_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bcf00_row1_col0" class="data row1 col0" >9e47792b-1540-4f4f-9748-db030f0787b1</td>
#       <td id="T_bcf00_row1_col1" class="data row1 col1" >http://w3id.org/ern-euro-nmd-fdp</td>
#       <td id="T_bcf00_row1_col2" class="data row1 col2" >ACTIVE</td>
#       <td id="T_bcf00_row1_col3" class="data row1 col3" >2023-02-27T08:15:55.984Z</td>
#       <td id="T_bcf00_row1_col4" class="data row1 col4" >2023-05-10T00:22:18.394Z</td>
#     </tr>
#     <tr>
#       <th id="T_bcf00_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bcf00_row2_col0" class="data row2 col0" >27d40e18-e1c6-45b1-940d-59105901bae8</td>
#       <td id="T_bcf00_row2_col1" class="data row2 col1" >https://w3id.org/ctsr-fdp</td>
#       <td id="T_bcf00_row2_col2" class="data row2 col2" >ACTIVE</td>
#       <td id="T_bcf00_row2_col3" class="data row2 col3" >2023-02-27T08:23:29.161Z</td>
#       <td id="T_bcf00_row2_col4" class="data row2 col4" >2023-05-10T00:22:18.237Z</td>
#     </tr>
#     <tr>
#       <th id="T_bcf00_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bcf00_row3_col0" class="data row3 col0" >255d928d-9f0b-4987-af9e-be9bf7d13392</td>
#       <td id="T_bcf00_row3_col1" class="data row3 col1" >https://w3id.org/smartcare-fdp</td>
#       <td id="T_bcf00_row3_col2" class="data row3 col2" >ACTIVE</td>
#       <td id="T_bcf00_row3_col3" class="data row3 col3" >2023-02-27T09:34:25.473Z</td>
#       <td id="T_bcf00_row3_col4" class="data row3 col4" >2023-05-10T00:22:18.236Z</td>
#     </tr>
#     <tr>
#       <th id="T_bcf00_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bcf00_row4_col0" class="data row4 col0" >d06f3341-bd37-426d-ad69-59fbf66ad043</td>
#       <td id="T_bcf00_row4_col1" class="data row4 col1" >https://w3id.org/fairvasc-fdp/</td>
#       <td id="T_bcf00_row4_col2" class="data row4 col2" >ACTIVE</td>
#       <td id="T_bcf00_row4_col3" class="data row4 col3" >2023-03-15T15:14:48.763Z</td>
#       <td id="T_bcf00_row4_col4" class="data row4 col4" >2023-05-11T13:06:59.397Z</td>
#     </tr>
#   </tbody>
# </table>

# %%
fetched_urls = set()

def parse_graph(graph, fdp, url):
    try:
        graph.parse(url, format="ttl")
        uris[fdp]["resolve"].append(url)
        fetched_urls.add(url)
        return True
    except Exception as e:
        print("Could not parse: " + url)
        uris[fdp]["not_resolve"].append(url)
        print(e)
        return False

def fetchMetaData(graph, fdp, url):
    if parse_graph(graph, fdp, url):
        query = """
        PREFIX ldp: <http://www.w3.org/ns/ldp#>
        SELECT ?o WHERE {
            # ?s ldp:contains ?o .
        }
        """
        results = graph.query(query)
        for row in results:
            resolve_url(graph, fdp, str(row["o"]) + "?format=ttl")

def resolve_url(graph, fdp, url):
    if parse_graph(graph, fdp, url):
        query = """
        PREFIX ldp: <http://www.w3.org/ns/ldp#>
        SELECT ?o WHERE {
            # ?s ldp:contains ?o .
        }
        """

        datasetsgraph = rdflib.Graph()
        if parse_graph(datasetsgraph, fdp, url):
            datasetsgraph.parse(url, format="ttl")
            datasetsTempResults = datasetsgraph.query(query)
            for row in datasetsTempResults:
                resolve_url(datasetsgraph, fdp, str(row["o"]) + "?format=ttl")
uris = {}
fdpgraph = dict()

for index, row in df.iterrows():
    if not row['clientUrl'].endswith('/'):
        row['clientUrl'] = row['clientUrl'] + '/'
    fdpgraph[row['clientUrl']] = rdflib.Graph()
    uris[row['clientUrl']] = {"resolve": [], "not_resolve": []}
    fetchMetaData(fdpgraph[row['clientUrl']], row['clientUrl'], row['clientUrl'] + "?format=ttl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 45
#      42 uris = {}
#      43 fdpgraph = dict()
# ---> 45 for index, row in df.iterrows():
#      46     if not row['clientUrl'].endswith('/'):
#      47         row['clientUrl'] = row['clientUrl'] + '/'
#
# NameError: name 'df' is not defined

# %%
for fdp in fdpgraph.keys():
    print(fdp)
    print(len(fdpgraph[fdp].all_nodes()))
# Out:
# https://w3id.org/duchenne-fdp/
# 140
# http://w3id.org/ern-euro-nmd-fdp/
# 87
# https://w3id.org/ctsr-fdp/
# 68
# https://w3id.org/smartcare-fdp/
# 76
# https://w3id.org/fairvasc-fdp/
# 66

# %%
# print("Fetching linked data from the web")
for fdp in fdpgraph.keys():
    # print(fdp)
    for node in fdpgraph[fdp].all_nodes():
        if isinstance(node, rdflib.URIRef):
            url = str(node)
            if url not in fetched_urls:
                try:
                    # print("Fetching: " + url)
                    fdpgraph[str(fdp)].parse(url)
                    uris[fdp]["resolve"].append(url)
                    fetched_urls.add(url)
                except:
                    uris[str(fdp)]["not_resolve"].append(url)
                    # print("Could not parse: " + url)
                    continue
# Out:
# Fetching linked data from the web
# https://w3id.org/duchenne-fdp/
# Fetching: http://purl.obolibrary.org/obo/HP_0033333
# Could not parse: http://purl.obolibrary.org/obo/HP_0033333
# Fetching: http://www.w3.org/ns/dcat#dataset
# Fetching: http://purl.obolibrary.org/obo/NCIT_C50184
# Fetching: http://id.loc.gov/vocabulary/iso639-1/en
# Fetching: http://purl.obolibrary.org/obo/HP_0033454
# Could not parse: http://purl.obolibrary.org/obo/HP_0033454
# Fetching: http://purl.obolibrary.org/obo/NCIT_C25271
# Fetching: http://purl.obolibrary.org/obo/NCIT_C141702
# Fetching: https://w3id.org/duchenne-fdp/catalog/
# Could not parse: https://w3id.org/duchenne-fdp/catalog/
# Fetching: https://www.wikidata.org/wiki/Q8777
# Could not parse: https://www.wikidata.org/wiki/Q8777
# Fetching: http://purl.org/spar/datacite/Identifier
# Could not parse: http://purl.org/spar/datacite/Identifier
# Fetching: http://purl.obolibrary.org/obo/NCIT_C176742
# Fetching: http://semanticscience.org/resource/CHEMINF_000047
# Fetching: http://purl.obolibrary.org/obo/HP_0020110
# Could not parse: http://purl.obolibrary.org/obo/HP_0020110
# Fetching: http://purl.obolibrary.org/obo/HP_0002650
# Could not parse: http://purl.obolibrary.org/obo/HP_0002650
# Fetching: https://w3id.org/duchenne-fdp#identifier
# Fetching: http://purl.obolibrary.org/obo/NCIT_C173346
# Fetching: http://purl.obolibrary.org/obo/UBERON_0001434
# Could not parse: http://purl.obolibrary.org/obo/UBERON_0001434
# Fetching: http://purl.obolibrary.org/obo/NCIT_C25656
# Fetching: http://purl.obolibrary.org/obo/HP_0002194
# Could not parse: http://purl.obolibrary.org/obo/HP_0002194
# Fetching: http://xmlns.com/foaf/0.1/Agent
# Could not parse: http://xmlns.com/foaf/0.1/Agent
# Fetching: http://purl.obolibrary.org/obo/HP_0009473
# Could not parse: http://purl.obolibrary.org/obo/HP_0009473
# Fetching: http://purl.obolibrary.org/obo/NCIT_C70810
# Fetching: http://purl.obolibrary.org/obo/NCIT_C130965
# Fetching: http://purl.obolibrary.org/obo/NCIT_C141706
# Fetching: http://www.orpha.net/ORDO/Orphanet_98895
# Could not parse: http://www.orpha.net/ORDO/Orphanet_98895
# Fetching: http://purl.obolibrary.org/obo/NCIT_C94198
# Fetching: http://purl.obolibrary.org/obo/NCIT_C20197
# Fetching: https://w3id.org/duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: https://w3id.org/duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: http://purl.obolibrary.org/obo/NCIT_C156186
# Fetching: http://purl.obolibrary.org/obo/NCIT_C13306
# Fetching: http://purl.obolibrary.org/obo/NCIT_C68615
# Fetching: http://purl.obolibrary.org/obo/HP_0008366
# Could not parse: http://purl.obolibrary.org/obo/HP_0008366
# Fetching: http://purl.obolibrary.org/obo/HP_0006380
# Could not parse: http://purl.obolibrary.org/obo/HP_0006380
# Fetching: http://www.w3.org/ns/dcat#DataService
# Fetching: http://purl.obolibrary.org/obo/NCIT_C132555
# Fetching: http://purl.obolibrary.org/obo/NCIT_C138901
# Fetching: https://w3id.org/duchenne-fdp/profile/a0949e72-4466-4d53-8900-9436d1049a4b
# Fetching: http://purl.obolibrary.org/obo/NCIT_C25279
# Fetching: http://purl.obolibrary.org/obo/NCIT_C16457
# Fetching: http://purl.obolibrary.org/obo/NCIT_C13359
# Fetching: http://purl.obolibrary.org/obo/HP_0002014
# Could not parse: http://purl.obolibrary.org/obo/HP_0002014
# Fetching: http://semanticscience.org/resource/SIO_000031
# Fetching: http://purl.obolibrary.org/obo/HP_0000750
# Could not parse: http://purl.obolibrary.org/obo/HP_0000750
# Fetching: https://w3id.org/duchenne-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: https://w3id.org/duchenne-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: http://purl.obolibrary.org/obo/HP_0005997
# Could not parse: http://purl.obolibrary.org/obo/HP_0005997
# Fetching: http://www.w3.org/ns/ldp#DirectContainer
# Fetching: http://purl.obolibrary.org/obo/NCIT_C121238
# Fetching: https://w3id.org/duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b#accessRights
# Fetching: http://purl.obolibrary.org/obo/NCIT_C93300
# Fetching: http://purl.obolibrary.org/obo/NCIT_C132531
# Fetching: http://purl.obolibrary.org/obo/NCIT_C171133
# Fetching: http://www.w3.org/ns/dcat#Resource
# Fetching: http://purl.obolibrary.org/obo/NCIT_C94321
# Fetching: https://w3id.org/duchenne-fdp#publisher
# Fetching: http://purl.obolibrary.org/obo/HP_0000708
# Could not parse: http://purl.obolibrary.org/obo/HP_0000708
# Fetching: https://w3id.org/duchenne-fdp#accessRights
# Fetching: https://w3id.org/fdp/fdp-o#MetadataService
# Could not parse: https://w3id.org/fdp/fdp-o#MetadataService
# Fetching: http://purl.obolibrary.org/obo/NCIT_C20993
# Fetching: http://purl.obolibrary.org/obo/NCIT_C115805
# Fetching: http://purl.obolibrary.org/obo/NCIT_C141687
# Fetching: http://purl.obolibrary.org/obo/NCIT_C62103
# Fetching: http://semanticscience.org/resource/SIO_000032
# Fetching: http://purl.obolibrary.org/obo/HP_0003270
# Could not parse: http://purl.obolibrary.org/obo/HP_0003270
# Fetching: http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd4.0
# Could not parse: http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd4.0
# Fetching: http://purl.obolibrary.org/obo/NCIT_C49887
# Fetching: http://purl.obolibrary.org/obo/HP_0002019
# Could not parse: http://purl.obolibrary.org/obo/HP_0002019
# Fetching: https://w3id.org/duchenne-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: https://w3id.org/duchenne-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: http://purl.obolibrary.org/obo/NCIT_C136154
# Fetching: http://purl.obolibrary.org/obo/HP_0032321
# Could not parse: http://purl.obolibrary.org/obo/HP_0032321
# Fetching: http://purl.obolibrary.org/obo/NCIT_C115789
# Fetching: https://w3id.org/duchenne-fdp
# Fetching: http://purl.obolibrary.org/obo/NCIT_C156420
# Fetching: http://purl.obolibrary.org/obo/HP_0008981
# Could not parse: http://purl.obolibrary.org/obo/HP_0008981
# Fetching: http://purl.org/dc/terms/RightsStatement
# Fetching: http://purl.obolibrary.org/obo/CMO_0000180
# Fetching: http://semanticscience.org/resource/SIO_000614
# Fetching: https://w3id.org/fdp/fdp-o#metadataCatalog
# Could not parse: https://w3id.org/fdp/fdp-o#metadataCatalog
# Fetching: http://purl.obolibrary.org/obo/NCIT_C102559
# Fetching: http://purl.obolibrary.org/obo/NCIT_C172685
# Fetching: http://purl.obolibrary.org/obo/HP_0006957
# Could not parse: http://purl.obolibrary.org/obo/HP_0006957
# Fetching: http://purl.obolibrary.org/obo/NCIT_C50276
# Fetching: http://www.w3.org/ns/dcat#Catalog
# Fetching: http://purl.obolibrary.org/obo/HP_0030193
# Could not parse: http://purl.obolibrary.org/obo/HP_0030193
# Fetching: http://purl.obolibrary.org/obo/CMO_0000005
# Fetching: http://purl.obolibrary.org/obo/MP_0012106
# Fetching: http://purl.obolibrary.org/obo/PATO_0001421
# Fetching: http://purl.obolibrary.org/obo/NCIT_C125410
# Fetching: http://purl.obolibrary.org/obo/HP_0001270
# Could not parse: http://purl.obolibrary.org/obo/HP_0001270
# Fetching: http://www.dpp_ontology.net/terms/Intermediate
# Could not parse: http://www.dpp_ontology.net/terms/Intermediate
# Fetching: https://w3id.org/duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b#identifier
# Fetching: http://semanticscience.org/resource/SIO_000061
# Fetching: http://purl.obolibrary.org/obo/NCIT_C122920
# Fetching: http://www.orpha.net/ORDO/Orphanet_98896
# Could not parse: http://www.orpha.net/ORDO/Orphanet_98896
# Fetching: http://purl.obolibrary.org/obo/NCIT_C131922
# Fetching: http://purl.obolibrary.org/obo/CMO_0000294
# Fetching: http://purl.obolibrary.org/obo/NCIT_C101668
# Fetching: http://purl.obolibrary.org/obo/HP_0002987
# Could not parse: http://purl.obolibrary.org/obo/HP_0002987
# Fetching: https://w3id.org/duchenne-fdp/dataset/3a2b5a69-b36f-4db9-983d-a1e410ba9c71
# Fetching: https://w3id.org/duchenne-fdp/dataset/
# Could not parse: https://w3id.org/duchenne-fdp/dataset/
# Fetching: http://purl.obolibrary.org/obo/NCIT_C141689
# Fetching: https://www.ietf.org/rfc/rfc3986.txt
# Could not parse: https://www.ietf.org/rfc/rfc3986.txt
# Fetching: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Could not parse: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Fetching: https://w3id.org/duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b
# Fetching: http://semanticscience.org/resource/SIO_010056
# Fetching: http://purl.obolibrary.org/obo/HP_0003044
# Could not parse: http://purl.obolibrary.org/obo/HP_0003044
# Fetching: http://purl.obolibrary.org/obo/NCIT_C15222
# Fetching: http://purl.obolibrary.org/obo/NCIT_C25711
# Fetching: http://purl.obolibrary.org/obo/HP_0002020
# Could not parse: http://purl.obolibrary.org/obo/HP_0002020
# Fetching: http://purl.obolibrary.org/obo/NCIT_C28421
# Fetching: http://purl.obolibrary.org/obo/HP_0000819
# Could not parse: http://purl.obolibrary.org/obo/HP_0000819
# Fetching: https://w3id.org/duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: https://w3id.org/duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Could not parse: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Fetching: http://purl.obolibrary.org/obo/NCIT_C16576
# Fetching: http://purl.obolibrary.org/obo/NCIT_C25597
# Fetching: http://purl.org/ejp-rd/vocabulary/VPQueryable
# Could not parse: http://purl.org/ejp-rd/vocabulary/VPQueryable
# Fetching: http://purl.obolibrary.org/obo/HP_0001263
# Could not parse: http://purl.obolibrary.org/obo/HP_0001263
# Fetching: https://w3id.org/duchenne-fdp/profile/77aaad6a-0136-4c6e-88b9-07ffccd0ee4c
# Fetching: http://purl.obolibrary.org/obo/NCIT_C15383
# http://w3id.org/ern-euro-nmd-fdp/
# Fetching: http://w3id.org/ern-euro-nmd-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: http://w3id.org/ern-euro-nmd-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: http://bioregistry.io/ncit:C101216
# Could not parse: http://bioregistry.io/ncit:C101216
# Fetching: http://w3id.org/ern-euro-nmd-fdp/profile/a0949e72-4466-4d53-8900-9436d1049a4b
# Fetching: http://bioregistry.io/obo:ICO_0000001
# Fetching: http://bioregistry.io/obo:OBIB_0000488
# Fetching: https://www.wikidata.org/wiki/Q8777
# Could not parse: https://www.wikidata.org/wiki/Q8777
# Fetching: http://purl.org/spar/datacite/Identifier
# Could not parse: http://purl.org/spar/datacite/Identifier
# Fetching: http://xmlns.com/foaf/0.1/Agent
# Could not parse: http://xmlns.com/foaf/0.1/Agent
# Fetching: http://www.orpha.net/ORDO/Orphanet_98503
# Could not parse: http://www.orpha.net/ORDO/Orphanet_98503
# Fetching: http://w3id.org/ern-euro-nmd-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: http://w3id.org/ern-euro-nmd-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: http://bioregistry.io/obo:OBI_0000810
# Fetching: http://bioregistry.io/obo:OBI_0001546
# Fetching: http://bioregistry.io/ncit:C84910
# Could not parse: http://bioregistry.io/ncit:C84910
# Fetching: http://w3id.org/ern-euro-nmd-fdp/profile/77aaad6a-0136-4c6e-88b9-07ffccd0ee4c
# Fetching: https://registry.ern-euro-nmd.eu/
# Could not parse: https://registry.ern-euro-nmd.eu/
# Fetching: http://bioregistry.io/ncit:C129000
# Could not parse: http://bioregistry.io/ncit:C129000
# Fetching: http://bioregistry.io/ncit:C28421
# Could not parse: http://bioregistry.io/ncit:C28421
# Fetching: http://w3id.org/ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443#identifier
# Fetching: http://w3id.org/ern-euro-nmd-fdp
# Fetching: http://bioregistry.io/ncit:C70810
# Could not parse: http://bioregistry.io/ncit:C70810
# Fetching: http://bioregistry.io/ncit:C18020
# Could not parse: http://bioregistry.io/ncit:C18020
# Fetching: http://w3id.org/ern-euro-nmd-fdp/catalog/
# Could not parse: http://w3id.org/ern-euro-nmd-fdp/catalog/
# Fetching: http://bioregistry.io/ncit:C25242
# Could not parse: http://bioregistry.io/ncit:C25242
# Fetching: http://bioregistry.io/sio:SIO_001389
# Could not parse: http://bioregistry.io/sio:SIO_001389
# Fetching: http://www.orpha.net/ORDO/Orphanet_98491
# Could not parse: http://www.orpha.net/ORDO/Orphanet_98491
# Fetching: http://purl.bioontology.org/ontology/LNC/MTHU854719
# Could not parse: http://purl.bioontology.org/ontology/LNC/MTHU854719
# Fetching: http://bioregistry.io/sio:SIO_010056
# Could not parse: http://bioregistry.io/sio:SIO_010056
# Fetching: http://w3id.org/ern-euro-nmd-fdp/dataset/5d6f2a12-4d8d-4f3a-ad83-b6e8f0fe9dc5
# Fetching: http://bioregistry.io/ncit:C15709
# Could not parse: http://bioregistry.io/ncit:C15709
# Fetching: http://w3id.org/ern-euro-nmd-fdp#accessRights
# Fetching: http://bioregistry.io/ncit:C4731
# Could not parse: http://bioregistry.io/ncit:C4731
# Fetching: https://w3id.org/fdp/fdp-o#MetadataService
# Could not parse: https://w3id.org/fdp/fdp-o#MetadataService
# Fetching: http://bioregistry.io/ncit:C16205
# Could not parse: http://bioregistry.io/ncit:C16205
# Fetching: http://bioregistry.io/sio:SIO_001381
# Could not parse: http://bioregistry.io/sio:SIO_001381
# Fetching: http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0
# Could not parse: http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0
# Fetching: http://bioregistry.io/obo:HP_0003674
# Could not parse: http://bioregistry.io/obo:HP_0003674
# Fetching: http://bioregistry.io/ncit:C159705
# Could not parse: http://bioregistry.io/ncit:C159705
# Fetching: https://w3id.org/fdp/fdp-o#metadataCatalog
# Could not parse: https://w3id.org/fdp/fdp-o#metadataCatalog
# Fetching: http://bioregistry.io/sio:SIO_001052
# Could not parse: http://bioregistry.io/sio:SIO_001052
# Fetching: http://bioregistry.io/ncit:C156420
# Could not parse: http://bioregistry.io/ncit:C156420
# Fetching: http://bioregistry.io/ncit:C68615
# Could not parse: http://bioregistry.io/ncit:C68615
# Fetching: http://w3id.org/ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: http://w3id.org/ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: http://w3id.org/ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443
# Fetching: http://www.orpha.net/ORDO/Orphanet_68380
# Could not parse: http://www.orpha.net/ORDO/Orphanet_68380
# Fetching: http://purl.org/ejp-rd/vocabulary/PatientRegistry
# Could not parse: http://purl.org/ejp-rd/vocabulary/PatientRegistry
# Fetching: http://bioregistry.io/edam:data_1153
# Could not parse: http://bioregistry.io/edam:data_1153
# Fetching: http://w3id.org/ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: http://w3id.org/ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: https://www.ietf.org/rfc/rfc3986.txt
# Could not parse: https://www.ietf.org/rfc/rfc3986.txt
# Fetching: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Could not parse: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Fetching: http://w3id.org/ern-euro-nmd-fdp/dataset/
# Could not parse: http://w3id.org/ern-euro-nmd-fdp/dataset/
# Fetching: http://w3id.org/ern-euro-nmd-fdp#identifier
# Fetching: http://w3id.org/ern-euro-nmd-fdp#publisher
# Fetching: http://www.orpha.net/ORDO/Orphanet_68381
# Could not parse: http://www.orpha.net/ORDO/Orphanet_68381
# Fetching: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Could not parse: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Fetching: http://w3id.org/ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443#accessRights
# Fetching: http://purl.org/ejp-rd/vocabulary/VPQueryable
# Could not parse: http://purl.org/ejp-rd/vocabulary/VPQueryable
# Fetching: http://bioregistry.io/ncit:C102741
# Could not parse: http://bioregistry.io/ncit:C102741
# Fetching: http://bioregistry.io/obo:DUO_0000001
# Could not parse: http://bioregistry.io/obo:DUO_0000001
# Fetching: http://bioregistry.io/sio:SIO_001001
# Could not parse: http://bioregistry.io/sio:SIO_001001
# https://w3id.org/ctsr-fdp/
# Fetching: https://w3id.org/ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b#accessRights
# Fetching: https://w3id.org/ctsr-fdp/site/19b1021e-7b67-454c-9a61-0d511854000f
# Fetching: https://w3id.org/ctsr-fdp/site/d42ffcf8-5d87-47e2-a1dd-8bd00294c75c
# Fetching: https://w3id.org/ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: https://w3id.org/ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: https://w3id.org/ctsr-fdp/dataset/b5bc04b6-bd1a-49f3-a5b3-a329b3ce6b9c
# Fetching: https://w3id.org/ctsr-fdp/dataset/
# Could not parse: https://w3id.org/ctsr-fdp/dataset/
# Fetching: https://creativecommons.org/licenses/by/4.0
# Could not parse: https://creativecommons.org/licenses/by/4.0
# Fetching: https://w3id.org/ctsr-fdp/profile/77aaad6a-0136-4c6e-88b9-07ffccd0ee4c
# Fetching: https://w3id.org/ctsr-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: https://w3id.org/ctsr-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: https://w3id.org/ctsr-fdp#identifier
# Fetching: https://w3id.org/ctsr-fdp
# Fetching: https://w3id.org/ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: https://w3id.org/ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: https://w3id.org/ctsr-fdp/catalog2/c1934541-a329-4139-96a2-a784c602b9da
# Could not parse: https://w3id.org/ctsr-fdp/catalog2/c1934541-a329-4139-96a2-a784c602b9da
# Fetching: https://www.wikidata.org/wiki/Q8777
# Could not parse: https://www.wikidata.org/wiki/Q8777
# Fetching: http://www.w3.org/ns/dcat#contactPoint
# Fetching: https://w3id.org/ctsr-fdp/profile/a0949e72-4466-4d53-8900-9436d1049a4b
# Fetching: http://purl.org/spar/datacite/Identifier
# Could not parse: http://purl.org/spar/datacite/Identifier
# Fetching: http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0
# Could not parse: http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0
# Fetching: https://w3id.org/ctsr-fdp/site/070a6704-67c5-4318-8643-5741e7222343
# Could not parse: https://w3id.org/ctsr-fdp/site/070a6704-67c5-4318-8643-5741e7222343
# Fetching: https://www.ietf.org/rfc/rfc3986.txt
# Could not parse: https://www.ietf.org/rfc/rfc3986.txt
# Fetching: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Could not parse: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Fetching: https://w3id.org/ctsr-fdp/contact_individual/9f1a623c-a114-40e3-866e-ab61bcb1aa57
# Could not parse: https://w3id.org/ctsr-fdp/contact_individual/9f1a623c-a114-40e3-866e-ab61bcb1aa57
# Fetching: https://w3id.org/ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b#identifier
# Fetching: https://w3id.org/ctsr-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: https://w3id.org/ctsr-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: https://w3id.org/ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b
# Fetching: http://www.w3.org/ns/dcat#catalog
# Fetching: https://w3id.org/ctsr-fdp/site/
# Could not parse: https://w3id.org/ctsr-fdp/site/
# Fetching: https://w3id.org/fdp/fdp-o#metadataCatalog
# Could not parse: https://w3id.org/fdp/fdp-o#metadataCatalog
# Fetching: https://w3id.org/ctsr-fdp/contact_organization/
# Could not parse: https://w3id.org/ctsr-fdp/contact_organization/
# Fetching: http://xmlns.com/foaf/0.1/Agent
# Could not parse: http://xmlns.com/foaf/0.1/Agent
# Fetching: https://w3id.org/ctsr-fdp#publisher
# Fetching: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Could not parse: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Fetching: https://w3id.org/ctsr-fdp/contact_organization/9452f804-c205-44b0-8472-9f88acebf899
# Could not parse: https://w3id.org/ctsr-fdp/contact_organization/9452f804-c205-44b0-8472-9f88acebf899
# Fetching: https://w3id.org/ctsr-fdp#accessRights
# Fetching: https://w3id.org/ctsr-fdp/contact_individual/
# Could not parse: https://w3id.org/ctsr-fdp/contact_individual/
# Fetching: https://w3id.org/ctsr-fdp/catalog/
# Could not parse: https://w3id.org/ctsr-fdp/catalog/
# Fetching: https://w3id.org/fdp/fdp-o#MetadataService
# Could not parse: https://w3id.org/fdp/fdp-o#MetadataService
# Fetching: https://w3id.org/ctsr-fdp/catalog2/8fa78605-8025-4e0c-bf63-4da64ee727a2
# Could not parse: https://w3id.org/ctsr-fdp/catalog2/8fa78605-8025-4e0c-bf63-4da64ee727a2
# Fetching: https://ctsr.uniklinik-freiburg.de/ctsr/
# Could not parse: https://ctsr.uniklinik-freiburg.de/ctsr/
# https://w3id.org/smartcare-fdp/
# Fetching: https://w3id.org/smartcare-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: https://w3id.org/smartcare-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: http://bioregistry.io/orphanet.ordo:83330
# Could not parse: http://bioregistry.io/orphanet.ordo:83330
# Fetching: https://w3id.org/smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: https://w3id.org/smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: http://bioregistry.io/orphanet.ordo:83420
# Could not parse: http://bioregistry.io/orphanet.ordo:83420
# Fetching: https://creativecommons.org/licenses/by/4.0
# Could not parse: https://creativecommons.org/licenses/by/4.0
# Fetching: http://bioregistry.io/ncit:C70810
# Could not parse: http://bioregistry.io/ncit:C70810
# Fetching: http://bioregistry.io/ncit:C166875
# Could not parse: http://bioregistry.io/ncit:C166875
# Fetching: https://w3id.org/smartcare-fdp#publisher
# Fetching: https://w3id.org/smartcare-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: https://w3id.org/smartcare-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: http://bioregistry.io/ncit:C167001
# Could not parse: http://bioregistry.io/ncit:C167001
# Fetching: http://bioregistry.io/ncit:C174715
# Could not parse: http://bioregistry.io/ncit:C174715
# Fetching: https://w3id.org/smartcare-fdp/dataset/
# Could not parse: https://w3id.org/smartcare-fdp/dataset/
# Fetching: https://w3id.org/smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10#identifier
# Fetching: http://bioregistry.io/orphanet.ordo:83418
# Could not parse: http://bioregistry.io/orphanet.ordo:83418
# Fetching: https://www.wikidata.org/wiki/Q8777
# Could not parse: https://www.wikidata.org/wiki/Q8777
# Fetching: https://w3id.org/smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: https://w3id.org/smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: http://bioregistry.io/ncit:C25242
# Could not parse: http://bioregistry.io/ncit:C25242
# Fetching: http://bioregistry.io/ncit:C115789
# Could not parse: http://bioregistry.io/ncit:C115789
# Fetching: http://purl.org/spar/datacite/Identifier
# Could not parse: http://purl.org/spar/datacite/Identifier
# Fetching: http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0
# Could not parse: http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0
# Fetching: http://bioregistry.io/omim:601627
# Could not parse: http://bioregistry.io/omim:601627
# Fetching: http://bioregistry.io/orphanet.ordo:83419
# Could not parse: http://bioregistry.io/orphanet.ordo:83419
# Fetching: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Could not parse: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Fetching: https://www.ietf.org/rfc/rfc3986.txt
# Could not parse: https://www.ietf.org/rfc/rfc3986.txt
# Fetching: https://w3id.org/smartcare-fdp#accessRights
# Fetching: http://bioregistry.io/orphanet.ordo:70
# Could not parse: http://bioregistry.io/orphanet.ordo:70
# Fetching: https://w3id.org/smartcare-fdp
# Fetching: https://w3id.org/smartcare-fdp/profile/a0949e72-4466-4d53-8900-9436d1049a4b
# Fetching: https://w3id.org/smartcare-fdp#identifier
# Fetching: https://w3id.org/smartcare-fdp/profile/77aaad6a-0136-4c6e-88b9-07ffccd0ee4c
# Fetching: https://w3id.org/smartcare-fdp/catalog/
# Could not parse: https://w3id.org/smartcare-fdp/catalog/
# Fetching: http://bioregistry.io/obo:HP_0003674
# Could not parse: http://bioregistry.io/obo:HP_0003674
# Fetching: http://bioregistry.io/ncit:C159705
# Could not parse: http://bioregistry.io/ncit:C159705
# Fetching: https://w3id.org/fdp/fdp-o#metadataCatalog
# Could not parse: https://w3id.org/fdp/fdp-o#metadataCatalog
# Fetching: https://w3id.org/smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10#accessRights
# Fetching: http://xmlns.com/foaf/0.1/Agent
# Could not parse: http://xmlns.com/foaf/0.1/Agent
# Fetching: https://www.smartcare.de/en/index.html
# Could not parse: https://www.smartcare.de/en/index.html
# Fetching: http://bioregistry.io/sio:SIO_001052
# Could not parse: http://bioregistry.io/sio:SIO_001052
# Fetching: http://bioregistry.io/ncit:C156420
# Could not parse: http://bioregistry.io/ncit:C156420
# Fetching: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Could not parse: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Fetching: https://w3id.org/smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10
# Fetching: https://w3id.org/smartcare-fdp/dataset/587f30b1-1775-4d25-a073-682c1f3f547a
# Fetching: http://bioregistry.io/ncit:C68615
# Could not parse: http://bioregistry.io/ncit:C68615
# Fetching: http://bioregistry.io/ncit:C129000
# Could not parse: http://bioregistry.io/ncit:C129000
# Fetching: https://w3id.org/fdp/fdp-o#MetadataService
# Could not parse: https://w3id.org/fdp/fdp-o#MetadataService
# Fetching: http://bioregistry.io/ncit:C28421
# Could not parse: http://bioregistry.io/ncit:C28421
# Fetching: http://bioregistry.io/sio:SIO_001001
# Could not parse: http://bioregistry.io/sio:SIO_001001
# Fetching: http://bioregistry.io/omim:600354
# Could not parse: http://bioregistry.io/omim:600354
# https://w3id.org/fairvasc-fdp/
# Fetching: https://w3id.org/fairvasc-fdp/dataset/7020751c-c26e-41bd-a3ef-1f783b12896a
# Fetching: https://w3id.org/fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05
# Fetching: https://w3id.org/fairvasc-fdp#accessRights
# Fetching: https://fairvasc.eu/
# Could not parse: https://fairvasc.eu/
# Fetching: https://w3id.org/fairvasc-fdp/dataset/186b032f-6c3a-4c34-b6e1-3b5956fe40a1
# Fetching: https://w3id.org/fairvasc-fdp/dataset/2f0d1c04-1dc7-4ad3-b427-35ebb88013b3
# Fetching: https://w3id.org/fairvasc-fdp
# Fetching: https://www.wikidata.org/wiki/Q8777
# Could not parse: https://www.wikidata.org/wiki/Q8777
# Fetching: https://w3id.org/fairvasc-fdp#publisher
# Fetching: http://purl.org/spar/datacite/Identifier
# Could not parse: http://purl.org/spar/datacite/Identifier
# Fetching: https://www.ietf.org/rfc/rfc3986.txt
# Could not parse: https://www.ietf.org/rfc/rfc3986.txt
# Fetching: https://w3id.org/fairvasc-fdp/dataset/5320bff0-9525-4b34-9525-e41767287f8b
# Fetching: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Could not parse: https://w3id.org/fdp/fdp-o#FAIRDataPoint
# Fetching: https://w3id.org/fairvasc-fdp/dataset/944d9f70-5f80-42c5-a0da-b8025e1dd6c2
# Could not parse: https://w3id.org/fairvasc-fdp/dataset/944d9f70-5f80-42c5-a0da-b8025e1dd6c2
# Fetching: https://w3id.org/fairvasc-fdp/profile/a0949e72-4466-4d53-8900-9436d1049a4b
# Fetching: https://w3id.org/fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05#accessRights
# Fetching: http://identifiers.org/orphanet:727
# Could not parse: http://identifiers.org/orphanet:727
# Fetching: https://w3id.org/fairvasc-fdp/catalog/
# Could not parse: https://w3id.org/fairvasc-fdp/catalog/
# Fetching: http://identifiers.org/orphanet:183
# Could not parse: http://identifiers.org/orphanet:183
# Fetching: https://w3id.org/fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: https://w3id.org/fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: https://w3id.org/fairvasc-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: https://w3id.org/fairvasc-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: https://w3id.org/fairvasc-fdp/dataset/ff0756fb-3cae-4c45-a905-4b386353261e
# Fetching: https://w3id.org/fdp/fdp-o#metadataCatalog
# Could not parse: https://w3id.org/fdp/fdp-o#metadataCatalog
# Fetching: https://w3id.org/fairvasc-fdp/dataset/0273ccc3-e5e4-4380-bb8c-0e4b8bf4e21c
# Fetching: http://xmlns.com/foaf/0.1/Agent
# Could not parse: http://xmlns.com/foaf/0.1/Agent
# Fetching: https://id.loc.gov/vocabulary/iso639-1/en
# Fetching: http://identifiers.org/orphanet:900
# Could not parse: http://identifiers.org/orphanet:900
# Fetching: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Could not parse: http://purl.org/ejp-rd/vocabulary/VPDiscoverable
# Fetching: https://w3id.org/fairvasc-fdp#identifier
# Fetching: https://w3id.org/fairvasc-fdp/profile/77aaad6a-0136-4c6e-88b9-07ffccd0ee4c
# Fetching: http://identifiers.org/orphanet:156152
# Could not parse: http://identifiers.org/orphanet:156152
# Fetching: https://w3id.org/fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05#identifier
# Fetching: https://w3id.org/fairvasc-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Could not parse: https://w3id.org/fairvasc-fdp/metrics/445c0a70d1e214e545b261559e2842f4
# Fetching: https://w3id.org/fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Could not parse: https://w3id.org/fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05/metrics/5d27e854a9e78eb3f663331cd47cdc13
# Fetching: https://w3id.org/fairvasc-fdp/dataset/
# Could not parse: https://w3id.org/fairvasc-fdp/dataset/
# Fetching: https://w3id.org/fdp/fdp-o#MetadataService
# Could not parse: https://w3id.org/fdp/fdp-o#MetadataService
# Fetching: http://dbpedia.org/resource/CC-BY_4.0

# %%
def save_dict_to_yaml(dictionary, filepath):
    with open(filepath, 'w') as file:
        yaml.dump(dictionary, file)

# Save dictionary as YAML
save_dict_to_yaml(uris, 'uriLogsfdptest.yaml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3         yaml.dump(dictionary, file)
#       5 # Save dictionary as YAML
# ----> 6 save_dict_to_yaml(uris, 'uriLogsfdptest.yaml')
#
# NameError: name 'uris' is not defined

# %%
with open('uriLogsfdptest', 'r') as file:
    data = yaml.safe_load(file)

resolve_counts = []
not_resolve_counts = []
servers = []

for server, values in data.items():
    resolve_count = len(values.get('resolve', []))
    not_resolve_count = len(values.get('not_resolve', []))
    servers.append(server)
    resolve_counts.append(resolve_count)
    not_resolve_counts.append(not_resolve_count)

plt.bar(servers, resolve_counts, label='Resolve')
plt.bar(servers, not_resolve_counts, label='Not Resolve', bottom=resolve_counts)
plt.xlabel('FDP')
plt.ylabel('Count')
plt.title('Counts of resolvable and non resolvable per FDP')
plt.legend()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
from urllib.parse import urlparse
urls = dict()

for fdp in data.keys():
    urls[fdp] = dict()
    for url in data[fdp]["not_resolve"]:

        urlsections = urlparse(url)
        paths = urlsections.path.strip('/').split('/')
        if urlsections.netloc not in urls[fdp].keys():
            urls[fdp][urlsections.netloc] = []
        urls[fdp][urlsections.netloc].append(urlsections.path)

urls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from urllib.parse import urlparse
#       2 urls = dict()
# ----> 4 for fdp in data.keys():
#       5     urls[fdp] = dict()
#       6     for url in data[fdp]["not_resolve"]:
#
# NameError: name 'data' is not defined

# %% [markdown]
# # 4 star LOD URIs

# %%
def dict_to_markdown_list(d):
    md = ''
    for k, v in d.items():
        if isinstance(v, list):
            md += f'- **{k}:**\n'
            for item in v:
                md += f'  - {item}\n'
        elif isinstance(v, dict):
            md += f'## {k}\n'
            md += dict_to_markdown_list(v)
        else:
            md += f'- **{k}:** {v}\n'
    return md

md = dict_to_markdown_list(urls)


display(Markdown(md))
# Out:
# ## http://w3id.org/ern-euro-nmd-fdp/
# - **w3id.org:**
#   - /ern-euro-nmd-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /ern-euro-nmd-fdp/metrics/445c0a70d1e214e545b261559e2842f4
#   - /ern-euro-nmd-fdp/catalog/
#   - /fdp/fdp-o
#   - /fdp/fdp-o
#   - /ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443/metrics/445c0a70d1e214e545b261559e2842f4
#   - /ern-euro-nmd-fdp/catalog/9e38450d-89cb-4f78-ac50-0f048a633443/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /fdp/fdp-o
#   - /ern-euro-nmd-fdp/dataset/
# - **bioregistry.io:**
#   - /ncit:C101216
#   - /ncit:C84910
#   - /ncit:C129000
#   - /ncit:C28421
#   - /ncit:C70810
#   - /ncit:C18020
#   - /ncit:C25242
#   - /sio:SIO_001389
#   - /sio:SIO_010056
#   - /ncit:C15709
#   - /ncit:C4731
#   - /ncit:C16205
#   - /sio:SIO_001381
#   - /obo:HP_0003674
#   - /ncit:C159705
#   - /sio:SIO_001052
#   - /ncit:C156420
#   - /ncit:C68615
#   - /edam:data_1153
#   - /ncit:C102741
#   - /obo:DUO_0000001
#   - /sio:SIO_001001
# - **www.wikidata.org:**
#   - /wiki/Q8777
# - **purl.org:**
#   - /spar/datacite/Identifier
#   - /ejp-rd/vocabulary/PatientRegistry
#   - /ejp-rd/vocabulary/VPDiscoverable
#   - /ejp-rd/vocabulary/VPQueryable
# - **xmlns.com:**
#   - /foaf/0.1/Agent
# - **www.orpha.net:**
#   - /ORDO/Orphanet_98503
#   - /ORDO/Orphanet_98491
#   - /ORDO/Orphanet_68380
#   - /ORDO/Orphanet_68381
# - **registry.ern-euro-nmd.eu:**
#   - /
# - **purl.bioontology.org:**
#   - /ontology/LNC/MTHU854719
# - **rdflicense.appspot.com:**
#   - /rdflicense/cc-by-nc-nd3.0
# - **www.ietf.org:**
#   - /rfc/rfc3986.txt
# ## https://w3id.org/ctsr-fdp/
# - **w3id.org:**
#   - /ctsr-fdp/catalog2/8fa78605-8025-4e0c-bf63-4da64ee727a2
#   - /ctsr-fdp/catalog2/c1934541-a329-4139-96a2-a784c602b9da
#   - /ctsr-fdp/diagnosis_cohort/410fd1da-df02-4df5-b839-821880c41fe4
#   - /ctsr-fdp/contact_organization/3aebd836-43fa-449a-8925-f2611d266650
#   - /ctsr-fdp/contact_organization/3aebd836-43fa-449a-8925-f2611d266650
#   - /ctsr-fdp/age_cohort/22a73747-d36f-41e3-815d-fcadcde9cd57
#   - /ctsr-fdp/site/070a6704-67c5-4318-8643-5741e7222343
#   - /ctsr-fdp/contact_individual/9f1a623c-a114-40e3-866e-ab61bcb1aa57
#   - /ctsr-fdp/contact_individual/9f1a623c-a114-40e3-866e-ab61bcb1aa57
#   - /ctsr-fdp/contact_organization/9452f804-c205-44b0-8472-9f88acebf899
#   - /ctsr-fdp/contact_organization/9452f804-c205-44b0-8472-9f88acebf899
#   - /ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /ctsr-fdp/dataset/
#   - /ctsr-fdp/metrics/445c0a70d1e214e545b261559e2842f4
#   - /ctsr-fdp/catalog/87acc8da-4885-4b73-85f4-7caaa062600b/metrics/445c0a70d1e214e545b261559e2842f4
#   - /ctsr-fdp/catalog2/c1934541-a329-4139-96a2-a784c602b9da
#   - /ctsr-fdp/site/070a6704-67c5-4318-8643-5741e7222343
#   - /fdp/fdp-o
#   - /ctsr-fdp/contact_individual/9f1a623c-a114-40e3-866e-ab61bcb1aa57
#   - /ctsr-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /ctsr-fdp/site/
#   - /fdp/fdp-o
#   - /ctsr-fdp/contact_organization/
#   - /ctsr-fdp/contact_organization/9452f804-c205-44b0-8472-9f88acebf899
#   - /ctsr-fdp/contact_individual/
#   - /ctsr-fdp/catalog/
#   - /fdp/fdp-o
#   - /ctsr-fdp/catalog2/8fa78605-8025-4e0c-bf63-4da64ee727a2
# - **creativecommons.org:**
#   - /licenses/by/4.0
# - **www.wikidata.org:**
#   - /wiki/Q8777
# - **purl.org:**
#   - /spar/datacite/Identifier
#   - /ejp-rd/vocabulary/VPDiscoverable
# - **rdflicense.appspot.com:**
#   - /rdflicense/cc-by-nc-nd3.0
# - **www.ietf.org:**
#   - /rfc/rfc3986.txt
# - **xmlns.com:**
#   - /foaf/0.1/Agent
# - **ctsr.uniklinik-freiburg.de:**
#   - /ctsr/
# ## https://w3id.org/duchenne-fdp/
# - **purl.obolibrary.org:**
#   - /obo/HP_0033333
#   - /obo/HP_0033454
#   - /obo/HP_0020110
#   - /obo/HP_0002650
#   - /obo/UBERON_0001434
#   - /obo/HP_0002194
#   - /obo/HP_0009473
#   - /obo/HP_0008366
#   - /obo/HP_0006380
#   - /obo/HP_0002014
#   - /obo/HP_0000750
#   - /obo/HP_0005997
#   - /obo/HP_0000708
#   - /obo/HP_0003270
#   - /obo/HP_0002019
#   - /obo/HP_0032321
#   - /obo/HP_0008981
#   - /obo/HP_0006957
#   - /obo/HP_0030193
#   - /obo/HP_0001270
#   - /obo/HP_0002987
#   - /obo/HP_0003044
#   - /obo/HP_0002020
#   - /obo/HP_0000819
#   - /obo/HP_0001263
# - **w3id.org:**
#   - /duchenne-fdp/catalog/
#   - /duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b/metrics/445c0a70d1e214e545b261559e2842f4
#   - /duchenne-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /fdp/fdp-o
#   - /duchenne-fdp/metrics/445c0a70d1e214e545b261559e2842f4
#   - /fdp/fdp-o
#   - /duchenne-fdp/dataset/
#   - /fdp/fdp-o
#   - /duchenne-fdp/catalog/ce01b2e8-3a1d-434e-b5e2-98e3a8d78a5b/metrics/5d27e854a9e78eb3f663331cd47cdc13
# - **www.wikidata.org:**
#   - /wiki/Q8777
# - **purl.org:**
#   - /spar/datacite/Identifier
#   - /ejp-rd/vocabulary/VPDiscoverable
#   - /ejp-rd/vocabulary/VPQueryable
# - **xmlns.com:**
#   - /foaf/0.1/Agent
# - **www.orpha.net:**
#   - /ORDO/Orphanet_98895
#   - /ORDO/Orphanet_98896
# - **rdflicense.appspot.com:**
#   - /rdflicense/cc-by-nc-nd4.0
# - **www.dpp_ontology.net:**
#   - /terms/Intermediate
# - **www.ietf.org:**
#   - /rfc/rfc3986.txt
# ## https://w3id.org/fairvasc-fdp/
# - **w3id.org:**
#   - /fairvasc-fdp/dataset/944d9f70-5f80-42c5-a0da-b8025e1dd6c2
#   - /fdp/fdp-o
#   - /fairvasc-fdp/dataset/944d9f70-5f80-42c5-a0da-b8025e1dd6c2
#   - /fairvasc-fdp/catalog/
#   - /fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05/metrics/445c0a70d1e214e545b261559e2842f4
#   - /fairvasc-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /fdp/fdp-o
#   - /fairvasc-fdp/metrics/445c0a70d1e214e545b261559e2842f4
#   - /fairvasc-fdp/catalog/b1cd4da5-566b-40c0-a70f-ef8390057a05/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /fairvasc-fdp/dataset/
#   - /fdp/fdp-o
# - **fairvasc.eu:**
#   - /
# - **www.wikidata.org:**
#   - /wiki/Q8777
# - **purl.org:**
#   - /spar/datacite/Identifier
#   - /ejp-rd/vocabulary/VPDiscoverable
# - **www.ietf.org:**
#   - /rfc/rfc3986.txt
# - **identifiers.org:**
#   - /orphanet:727
#   - /orphanet:183
#   - /orphanet:900
#   - /orphanet:156152
# - **xmlns.com:**
#   - /foaf/0.1/Agent
# ## https://w3id.org/smartcare-fdp/
# - **w3id.org:**
#   - /smartcare-fdp/metrics/445c0a70d1e214e545b261559e2842f4
#   - /smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /smartcare-fdp/metrics/5d27e854a9e78eb3f663331cd47cdc13
#   - /smartcare-fdp/dataset/
#   - /smartcare-fdp/catalog/f453e170-5a9f-4e30-bb35-649e9690be10/metrics/445c0a70d1e214e545b261559e2842f4
#   - /fdp/fdp-o
#   - /smartcare-fdp/catalog/
#   - /fdp/fdp-o
#   - /fdp/fdp-o
# - **bioregistry.io:**
#   - /orphanet.ordo:83330
#   - /orphanet.ordo:83420
#   - /ncit:C70810
#   - /ncit:C166875
#   - /ncit:C167001
#   - /ncit:C174715
#   - /orphanet.ordo:83418
#   - /ncit:C25242
#   - /ncit:C115789
#   - /omim:601627
#   - /orphanet.ordo:83419
#   - /orphanet.ordo:70
#   - /obo:HP_0003674
#   - /ncit:C159705
#   - /sio:SIO_001052
#   - /ncit:C156420
#   - /ncit:C68615
#   - /ncit:C129000
#   - /ncit:C28421
#   - /sio:SIO_001001
#   - /omim:600354
# - **creativecommons.org:**
#   - /licenses/by/4.0
# - **www.wikidata.org:**
#   - /wiki/Q8777
# - **purl.org:**
#   - /spar/datacite/Identifier
#   - /ejp-rd/vocabulary/VPDiscoverable
# - **rdflicense.appspot.com:**
#   - /rdflicense/cc-by-nc-nd3.0
# - **www.ietf.org:**
#   - /rfc/rfc3986.txt
# - **xmlns.com:**
#   - /foaf/0.1/Agent
# - **www.smartcare.de:**
#   - /en/index.html
